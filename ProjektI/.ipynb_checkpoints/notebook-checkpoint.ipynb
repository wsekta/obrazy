# %%
from functions import *
from matplotlib import image
from matplotlib import pyplot

# %%
mono = image.imread('cameraman.bmp')
color = image.imread('peppers.jpg')
logical = image.imread('wklensla.png')
logical = (logical / 255).astype("bool")[:,:,0]

# %%
pyplot.imshow(mono, cmap="Greys_r")

# %%
pyplot.imshow(color)

# %%
pyplot.imshow(logical, cmap="Greys_r")

# %% [markdown]
# # Normalizacja obrazu według łamanej

# %% [markdown]
# krzywą podajemy jako listę tupli z dwoma liczbami z zakresu 0-255

# %%
pyplot.imshow(normalize_by_polyline(mono,[(50,100),(150,150),(200,250)]), cmap="Greys_r")

# %%
pyplot.imshow(normalize_by_polyline(color,[(50,100),(150,150),(200,250)]))

# %% [markdown]
# # Filtracja entropii

# %%
pyplot.imshow(entropy_filter(mono, 5), cmap="Greys_r")

# %%
pyplot.imshow(entropy_filter(logical, 5), cmap="Greys_r")

# %%
pyplot.imshow(entropy_filter(color, 5), cmap="Greys_r")

# %% [markdown]
# # Otwarcie elementem linijnym

# %%
pyplot.imshow(imopen(mono,10,30), cmap="Greys_r")

# %%
pyplot.imshow(imopen(logical,10,30), cmap="Greys_r")

# %% [markdown]
# # Wypukłe otoczenie

# %%
pyplot.imshow(convex_hull(logical), cmap="Greys_r")
